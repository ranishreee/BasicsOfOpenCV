# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full_img = cv2.imread('Mug_Orange.jpeg')
full_img = cv2.cvtColor(full_img,cv2.COLOR_BGR2RGB)

seg_img = cv2.imread('Mug01.jpeg')
seg_img = cv2.cvtColor(seg_img,cv2.COLOR_BGR2RGB)

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for n in methods:
    full_copy = full_img.copy()
    method = eval(n)
    
    res = cv2.matchTemplate(full_img,seg_img,method)
    min,max,min_loc,max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
        
    height,width,channels = face.shape
    
    bottom_Right = (top_left[0]+width , top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left,bottom_Right,(200,0,0),15)

    plt.subplot(121)
    plt.imshow(res)
    plt.title('HEATMAP')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('Detected Image')
    plt.suptitle(n)
    
    plt.show()
    print('\n')
    print('\n')
